# %% [markdown]
# # Capstone Project - Battle of Neighborhoods (week 2)
#
# # Applied Data Science Capstone
#
# ## Introduction to Business Problem
#
# Opening a new French Restaurant in Houston,Texas.
# The objective of this report is to determine the best possible location to open a new French Restaurant in Houston. it will be based on the different localities of the city, already established French restaurants in various geographical location and ease of accessibility by maximum number of people so that the revenue from the latest venture can be maximized.
#
# ## Data
#
# In this project I will use data from :
# Geopy - For getting the co-ordinated of different locations.
# Foursquare API - To get the list of venues and their details around a given location.

# %% [markdown]
# ## Methodology
#
# Getting the co-ordinates of the target city.
# Getting the list of neighborhoods and their co-ordinates.
# Exploring the most visited venues in the target localities.
# Clustering the localities.
# Analyzing the clusters formed.
# Collecting information about the type of restaurants already present in a locality.
# Creating a machine learning model based on data acquired.
# Using the model to predict the locality best suited for upcoming Italian Resataurant.

# %%
import numpy as np # library to handle data in a vectorized manner
import time
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %%
import sys
! pip install geocoder
! pip install folium
! pip install SomePackage
! pip install numpy
! pip install BeautifulSoup4
! pip install wikipedia
! pip install bs4
! pip install IPython
! pip install lxml
! pip install Nominatim
! pip install geopy

print('Packages installed.')
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 9.1MB/s ta 0:00:011
# Collecting click (from geocoder)
#   Using cached https://files.pythonhosted.org/packages/d2/3d/fa76db83bf75c4f8d338c2fd15c8d33fdd7ad23a9b5e57eb6c5de26b430e/click-7.1.2-py2.py3-none-any.whl
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (1.15.0)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (2.25.0)
# Collecting ratelim (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Collecting future (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz (829kB)
#      |████████████████████████████████| 829kB 21.4MB/s eta 0:00:01
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (1.26.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ratelim->geocoder) (4.4.2)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# Successfully built future
# Installing collected packages: click, ratelim, future, geocoder
# Successfully installed click-7.1.2 future-0.18.2 geocoder-1.38.1 ratelim-0.1.6
# Requirement already satisfied: folium in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.5.0)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (2.25.0)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (1.15.0)
# Requirement already satisfied: branca in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (0.4.1)
# Requirement already satisfied: jinja2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (2.11.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (1.26.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2->folium) (1.1.1)
# Collecting SomePackage
#   Downloading https://files.pythonhosted.org/packages/81/f6/cdc617199548a495fd034a4128bb33b35857d2ddb97ddf25c4f29302569e/somepackage-1.2.3.tar.gz
# Building wheels for collected packages: SomePackage
#   Building wheel for SomePackage (setup.py) ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/8f/99/38/629e5a3389c43538eb1c242508e84750aefbf4894a65ef5b1f
# Successfully built SomePackage
# Installing collected packages: SomePackage
# Successfully installed SomePackage-1.2.3
# Requirement already satisfied: numpy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.19.4)
# Collecting BeautifulSoup4
#   Downloading https://files.pythonhosted.org/packages/d1/41/e6495bd7d3781cee623ce23ea6ac73282a373088fcd0ddc809a047b18eae/beautifulsoup4-4.9.3-py3-none-any.whl (115kB)
#      |████████████████████████████████| 122kB 5.8MB/s eta 0:00:01
# Collecting soupsieve>1.2; python_version >= "3.0" (from BeautifulSoup4)
#   Downloading https://files.pythonhosted.org/packages/02/fb/1c65691a9aeb7bd6ac2aa505b84cb8b49ac29c976411c6ab3659425e045f/soupsieve-2.1-py3-none-any.whl
# Installing collected packages: soupsieve, BeautifulSoup4
# Successfully installed BeautifulSoup4-4.9.3 soupsieve-2.1
# Collecting wikipedia
#   Downloading https://files.pythonhosted.org/packages/67/35/25e68fbc99e672127cc6fbb14b8ec1ba3dfef035bf1e4c90f78f24a80b7d/wikipedia-1.4.0.tar.gz
# Requirement already satisfied: beautifulsoup4 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from wikipedia) (4.9.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from wikipedia) (2.25.0)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from beautifulsoup4->wikipedia) (2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.10)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py) ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/87/2a/18/4e471fd96d12114d16fe4a446d00c3b38fb9efcb744bd31f4a
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Requirement already satisfied: beautifulsoup4 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from beautifulsoup4->bs4) (2.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1
# Requirement already satisfied: IPython in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (7.16.1)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from IPython) (4.4.2)
# Requirement already satisfied: backcall in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from IPython) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from IPython) (3.0.8)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from IPython) (4.8.0)
# Requirement already satisfied: pygments in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from IPython) (2.7.3)
# Requirement already satisfied: traitlets>=4.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from IPython) (4.3.3)
# Requirement already satisfied: jedi>=0.10 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from IPython) (0.17.2)
# Requirement already satisfied: pickleshare in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from IPython) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from IPython) (49.6.0.post20201009)
# Requirement already satisfied: wcwidth in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->IPython) (0.6.0)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from traitlets>=4.2->IPython) (1.15.0)
# Requirement already satisfied: ipython-genutils in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from traitlets>=4.2->IPython) (0.2.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jedi>=0.10->IPython) (0.7.1)
# Collecting lxml
#   Downloading https://files.pythonhosted.org/packages/bd/78/56a7c88a57d0d14945472535d0df9fb4bbad7d34ede658ec7961635c790e/lxml-4.6.2-cp36-cp36m-manylinux1_x86_64.whl (5.5MB)
#      |████████████████████████████████| 5.5MB 7.7MB/s eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-4.6.2
# Collecting Nominatim
#   Downloading https://files.pythonhosted.org/packages/59/f2/d47726f804208804f7f295e20a9d2ee4ea925fb6462481223464026bcf66/nominatim-0.1.tar.gz
# Building wheels for collected packages: Nominatim
#   Building wheel for Nominatim (setup.py) ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/d5/66/ed/e7476981dc30210b6b5ce7c25b054e8db35d44fdd2198003d4
# Successfully built Nominatim
# Installing collected packages: Nominatim
# Successfully installed Nominatim-0.1
# Collecting geopy
#   Downloading https://files.pythonhosted.org/packages/07/e1/9c72de674d5c2b8fcb0738a5ceeb5424941fefa080bfe4e240d0bacb5a38/geopy-2.0.0-py3-none-any.whl (111kB)
#      |████████████████████████████████| 112kB 15.1MB/s eta 0:00:01
# Collecting geographiclib<2,>=1.49 (from geopy)
#   Downloading https://files.pythonhosted.org/packages/8b/62/26ec95a98ba64299163199e95ad1b0e34ad3f4e176e221c40245f211e425/geographiclib-1.50-py3-none-any.whl
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-2.0.0
# Packages installed.

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36he6145b8_1001         347 KB  conda-forge
#     chardet-3.0.4              |py36h9880bd3_1008         194 KB  conda-forge
#     cryptography-3.3.1         |   py36h0a59100_0         624 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     openssl-1.1.1i             |       h7f98852_0         2.1 MB  conda-forge
#     pandas-1.1.5               |   py36h284efc9_0        11.3 MB  conda-forge
#     pysocks-1.7.1              |   py36h9880bd3_2          27 KB  conda-forge
#     toolz-0.11.1               |             py_0          46 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        15.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-20.3.0-pyhd3deb0d_0
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36he6145b8_1001
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9880bd3_1008
#   cryptography       conda-forge/linux-64::cryptography-3.3.1-py36h0a59100_0
#   entrypoints        conda-forge/noarch::entrypoints-0.3-pyhd8ed1ab_1003
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.10-pyh9f0ad1d_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-3.1.1-hd8ed1ab_0
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/noarch::jsonschema-3.2.0-py_2
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36he6145b8_2
#   pandas             conda-forge/linux-64::pandas-1.1.5-py36h284efc9_0
#   pyopenssl          conda-forge/noarch::pyopenssl-20.0.0-pyhd8ed1ab_0
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.17.3-py36h1d69622_1
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9880bd3_2
#   pytz               conda-forge/noarch::pytz-2020.4-pyhd8ed1ab_0
#   requests           conda-forge/noarch::requests-2.25.0-pyhd3deb0d_0
#   toolz              conda-forge/noarch::toolz-0.11.1-py_0
#   urllib3            conda-forge/noarch::urllib3-1.25.11-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1h-h516909a_0 --> 1.1.1i-h7f98852_0
#
#
#
# Downloading and Extracting Packages
# pandas-1.1.5         | 11.3 MB   | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# brotlipy-0.7.0       | 347 KB    | ##################################### | 100%
# cryptography-3.3.1   | 624 KB    | ##################################### | 100%
# chardet-3.0.4        | 194 KB    | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# openssl-1.1.1i       | 2.1 MB    | ##################################### | 100%
# toolz-0.11.1         | 46 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
address = 'Houston, Texas'
geolocator = Nominatim(user_agent="my_user_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Houston are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Houston are 29.7589382, -95.3676974.

# %% [markdown]
# Houston neighborhood_latitude = 29.7589382
# Houston neighborhood_longitude = -95.3676974

# %% [markdown]
# Dial FourSquare to find venues around current residence in Houston Texas

# %%
CLIENT_ID = '1CVX0P22PGNHR2GYDNEIYSSE5UZHVOGVTVADWQXJ5NF5BKJ1' # your Foursquare ID
CLIENT_SECRET = 'client secret' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 1CVX0P22PGNHR2GYDNEIYSSE5UZHVOGVTVADWQXJ5NF5BKJ1
# CLIENT_SECRET:client secret

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 1000 # define radius

# %%
# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=1CVX0P22PGNHR2GYDNEIYSSE5UZHVOGVTVADWQXJ5NF5BKJ1&client_secret=NU3QOJRDYYVJN0125XOZDZFQGLYVYSC5R5IEGBHXHL0SFFRO&v=20180604&ll=29.7589382,-95.3676974&radius=1000&limit=100'

# %%
results = requests.get(url).json()
#results

# %%
import numpy as np # library to handle data in a vectorized manner
import time
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fd6d2774fe037099c6bee8c'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Downtown Houston',
#   'headerFullLocation': 'Downtown Houston, Houston',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 184,
#   'suggestedBounds': {'ne': {'lat': 29.767938209000008,
#     'lng': -95.35734953273267},
#    'sw': {'lat': 29.74993819099999, 'lng': -95.37804526726732}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56cf664a498eec17aaf5f939',
#        'name': 'Mango Tree Thai Bistro',
#        'location': {'address': '914 Main Street Houston',
#         'crossStreet': 'Walker And Travis',
#         'lat': 29.7582507801515,
#         'lng': -95.36538711279135,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7582507801515,
#           'lng': -95.36538711279135}],
#         'distance': 236,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['914 Main Street Houston (Walker And Travis)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56cf664a498eec17aaf5f939-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbb8ef0e452952192d954a4',
#        'name': "Jason's Deli",
#        'location': {'address': '901 McKinney St',
#         'lat': 29.75746388891063,
#         'lng': -95.36554282298964,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75746388891063,
#           'lng': -95.36554282298964}],
#         'distance': 265,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['901 McKinney St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbb8ef0e452952192d954a4-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae4e065f964a5200d9f21e3',
#        'name': 'Hobby Center for the Performing Arts',
#        'location': {'address': '800 Bagby St',
#         'crossStreet': 'btwn Rusk St & Walker St',
#         'lat': 29.761525580635887,
#         'lng': -95.36937625723134,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.761525580635887,
#           'lng': -95.36937625723134},
#          {'label': 'entrance', 'lat': 29.761447, 'lng': -95.369286}],
#         'distance': 330,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['800 Bagby St (btwn Rusk St & Walker St)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f2931735',
#          'name': 'Performing Arts Venue',
#          'pluralName': 'Performing Arts Venues',
#          'shortName': 'Performing Arts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae4e065f964a5200d9f21e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd9ae2d2e6f0f47c9730b08',
#        'name': 'Becks Prime',
#        'location': {'address': '910 Travis St',
#         'lat': 29.75818486875766,
#         'lng': -95.36617176399422,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75818486875766,
#           'lng': -95.36617176399422}],
#         'distance': 169,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['910 Travis St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1818373',
#         'url': 'https://www.grubhub.com/restaurant/becks-prime-919-milam-st-houston/1818373?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1818373',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd9ae2d2e6f0f47c9730b08-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aa33650f964a520b34320e3',
#        'name': 'Alley Theatre',
#        'location': {'address': '615 Texas St',
#         'crossStreet': 'btw Louisiana and Smith',
#         'lat': 29.761671455030886,
#         'lng': -95.36531338369234,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.761671455030886,
#           'lng': -95.36531338369234},
#          {'label': 'entrance', 'lat': 29.761917, 'lng': -95.36545}],
#         'distance': 381,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['615 Texas St (btw Louisiana and Smith)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '41358382'}},
#       'referralId': 'e-0-4aa33650f964a520b34320e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1ae482f964a52018f423e3',
#        'name': 'Jones Hall',
#        'location': {'address': '615 Louisiana St #101',
#         'lat': 29.761239817549807,
#         'lng': -95.36530148121828,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.761239817549807,
#           'lng': -95.36530148121828},
#          {'label': 'entrance', 'lat': 29.760979, 'lng': -95.36544}],
#         'distance': 345,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['615 Louisiana St #101',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '5032792091d4c4b30a586d5c',
#          'name': 'Concert Hall',
#          'pluralName': 'Concert Halls',
#          'shortName': 'Concert Hall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1ae482f964a52018f423e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5a3ea4f964a52021b728e3',
#        'name': 'Bombay Pizza Co.',
#        'location': {'address': '914 Main St Ste 105',
#         'crossStreet': 'Walker St',
#         'lat': 29.7577,
#         'lng': -95.364586,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7577,
#           'lng': -95.364586}],
#         'distance': 330,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['914 Main St Ste 105 (Walker St)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '245629',
#         'url': 'https://www.grubhub.com/restaurant/bombay-pizza-co-914-main-st-houston/245629?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=245629',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5a3ea4f964a52021b728e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b510fe4f964a520554027e3',
#        'name': 'Perbacco',
#        'location': {'address': '700 Milam St',
#         'lat': 29.760257437720647,
#         'lng': -95.36477339516325,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.760257437720647,
#           'lng': -95.36477339516325},
#          {'label': 'entrance', 'lat': 29.760076, 'lng': -95.365164}],
#         'distance': 318,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['700 Milam St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1914930',
#         'url': 'https://www.grubhub.com/restaurant/perbacco-700-milam-street-houston/1914930?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1914930',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b510fe4f964a520554027e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb5faedb315a093cf999876',
#        'name': "City Hall Farmer's Market",
#        'location': {'address': '901 Bagby St',
#         'lat': 29.759163880661635,
#         'lng': -95.36844616089815,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.759163880661635,
#           'lng': -95.36844616089815}],
#         'distance': 76,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['901 Bagby St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa941735',
#          'name': 'Farmers Market',
#          'pluralName': 'Farmers Markets',
#          'shortName': "Farmer's Market",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb5faedb315a093cf999876-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae46c23f964a520819a21e3',
#        'name': 'Sam Houston Park',
#        'location': {'address': '1100 Bagby St',
#         'lat': 29.75987637162599,
#         'lng': -95.37121094173017,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75987637162599,
#           'lng': -95.37121094173017}],
#         'distance': 355,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1100 Bagby St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae46c23f964a520819a21e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac96394f964a520cfbf20e3',
#        'name': 'Houston Symphony',
#        'location': {'address': '615 Louisiana St Ste 102',
#         'lat': 29.7608909,
#         'lng': -95.36500439999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7608909,
#           'lng': -95.36500439999999},
#          {'label': 'entrance', 'lat': 29.760979, 'lng': -95.36544}],
#         'distance': 339,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['615 Louisiana St Ste 102',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f2931735',
#          'name': 'Performing Arts Venue',
#          'pluralName': 'Performing Arts Venues',
#          'shortName': 'Performing Arts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac96394f964a520cfbf20e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '41326e00f964a520f9111fe3',
#        'name': 'Flying Saucer Draught Emporium',
#        'location': {'address': '705 Main St',
#         'crossStreet': 'Capitol St',
#         'lat': 29.759116074765853,
#         'lng': -95.36321640522559,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.759116074765853,
#           'lng': -95.36321640522559}],
#         'distance': 433,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['705 Main St (Capitol St)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#          'name': 'Beer Bar',
#          'pluralName': 'Beer Bars',
#          'shortName': 'Beer Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1569013',
#         'url': 'https://www.grubhub.com/restaurant/flying-saucer-705-main-street-houston/1569013?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1569013',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-41326e00f964a520f9111fe3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05bd3ef964a5201ae222e3',
#        'name': 'Theatre Under The Stars',
#        'location': {'address': '800 Bagby St Ste 200',
#         'lat': 29.761486842951108,
#         'lng': -95.37006806125714,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.761486842951108,
#           'lng': -95.37006806125714},
#          {'label': 'entrance', 'lat': 29.761447, 'lng': -95.369286}],
#         'distance': 364,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['800 Bagby St Ste 200',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b05bd3ef964a5201ae222e3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '598a39f9123a19503bef4e46',
#        'name': 'Finn Hall',
#        'location': {'address': '712 Main St',
#         'lat': 29.758677697696452,
#         'lng': -95.36384585056344,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.758677697696452,
#           'lng': -95.36384585056344}],
#         'distance': 373,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['712 Main St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-598a39f9123a19503bef4e46-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '519233a2abd8f61181645e44',
#        'name': 'JW Marriott Houston Downtown',
#        'location': {'address': '806 Main St',
#         'lat': 29.7583321,
#         'lng': -95.3640592,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7583321,
#           'lng': -95.3640592}],
#         'distance': 358,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['806 Main St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '86910968'}},
#       'referralId': 'e-0-519233a2abd8f61181645e44-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b22fa2af964a5206d5124e3',
#        'name': 'Wortham Theater Center',
#        'location': {'address': '501 Texas St',
#         'crossStreet': 'Smith Street',
#         'lat': 29.76335289300658,
#         'lng': -95.36566257476807,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.76335289300658,
#           'lng': -95.36566257476807}],
#         'distance': 529,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['501 Texas St (Smith Street)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b22fa2af964a5206d5124e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '583491fb409f5673e5c8440f',
#        'name': '5411 Empanadas',
#        'location': {'address': '811 Louisiana St',
#         'crossStreet': 'Downtown Houston Tunnel',
#         'lat': 29.758986,
#         'lng': -95.36859,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.758986,
#           'lng': -95.36859}],
#         'distance': 86,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['811 Louisiana St (Downtown Houston Tunnel)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '52939a8c3cf9994f4e043a35',
#          'name': 'Empanada Restaurant',
#          'pluralName': 'Empanada Restaurants',
#          'shortName': 'Empanada',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-583491fb409f5673e5c8440f-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b42392df964a52060cf25e3',
#        'name': 'Treebeards - The Tunnel',
#        'location': {'address': '1100 Louisiana St',
#         'crossStreet': 'Tunnel',
#         'lat': 29.75790324188933,
#         'lng': -95.36897178076335,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75790324188933,
#           'lng': -95.36897178076335},
#          {'label': 'entrance', 'lat': 29.757735, 'lng': -95.368642}],
#         'distance': 168,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1100 Louisiana St (Tunnel)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'shortName': 'Southern / Soul',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b42392df964a52060cf25e3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4b5994f964a5205c9826e3',
#        'name': 'Whataburger',
#        'location': {'address': '1000 Main St',
#         'crossStreet': 'at McKinney St',
#         'lat': 29.7567977,
#         'lng': -95.3656692,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7567977,
#           'lng': -95.3656692}],
#         'distance': 308,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1000 Main St (at McKinney St)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1580601',
#         'url': 'https://www.grubhub.com/restaurant/whataburger-1000-main-street-houston/1580601?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1580601',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4b5994f964a5205c9826e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5f3527f964a52054ad29e3',
#        'name': 'Houstonian Lite',
#        'location': {'address': '711 Louisiana St',
#         'crossStreet': 'btwn Rusk & Capitol',
#         'lat': 29.760524419286174,
#         'lng': -95.36572750369359,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.760524419286174,
#           'lng': -95.36572750369359},
#          {'label': 'entrance', 'lat': 29.760177, 'lng': -95.366066}],
#         'distance': 259,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['711 Louisiana St (btwn Rusk & Capitol)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5f3527f964a52054ad29e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ada6409f964a520352221e3',
#        'name': "Frank's Pizza",
#        'location': {'address': '417 Travis St',
#         'crossStreet': 'btw Preston & Prairie',
#         'lat': 29.76139343862214,
#         'lng': -95.36272077712701,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.76139343862214,
#           'lng': -95.36272077712701},
#          {'label': 'entrance', 'lat': 29.761383, 'lng': -95.362611}],
#         'distance': 553,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['417 Travis St (btw Preston & Prairie)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ada6409f964a520352221e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '563d489bcd10abb6a12f5f3e',
#        'name': 'Pappas Bros. Steakhouse',
#        'location': {'address': '1200 McKinney St',
#         'lat': 29.75554477067771,
#         'lng': -95.36312583068846,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75554477067771,
#           'lng': -95.36312583068846}],
#         'distance': 581,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1200 McKinney St',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-563d489bcd10abb6a12f5f3e-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b057edaf964a520c85822e3',
#        'name': 'Hyatt Regency Houston',
#        'location': {'address': '1200 Louisiana St',
#         'lat': 29.7570493,
#         'lng': -95.36945999999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7570493,
#           'lng': -95.36945999999999}],
#         'distance': 270,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1200 Louisiana St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b057edaf964a520c85822e3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54da67fc498ef16e5489131e',
#        'name': 'Conservatory',
#        'location': {'address': '1010 Prairie St',
#         'lat': 29.760427,
#         'lng': -95.36157,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.760427,
#           'lng': -95.36157}],
#         'distance': 614,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1010 Prairie St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d117941735',
#          'name': 'Beer Garden',
#          'pluralName': 'Beer Gardens',
#          'shortName': 'Beer Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54da67fc498ef16e5489131e-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbe9a4085fbb713a61d7167',
#        'name': 'Houston Grand Opera',
#        'location': {'address': '510 Preston St',
#         'lat': 29.76362297525448,
#         'lng': -95.36520404590503,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.76362297525448,
#           'lng': -95.36520404590503},
#          {'label': 'entrance', 'lat': 29.763704, 'lng': -95.365218}],
#         'distance': 574,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['510 Preston St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '5032792091d4c4b30a586d5c',
#          'name': 'Concert Hall',
#          'pluralName': 'Concert Halls',
#          'shortName': 'Concert Hall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbe9a4085fbb713a61d7167-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5737c72e498eeae08464d62a',
#        'name': 'Aloft Houston Downtown',
#        'location': {'address': '820 Fannin St',
#         'lat': 29.75751314468994,
#         'lng': -95.36357581615448,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75751314468994,
#           'lng': -95.36357581615448}],
#         'distance': 428,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['820 Fannin St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5737c72e498eeae08464d62a-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ada75a8f964a520c32221e3',
#        'name': 'House of Blues',
#        'location': {'address': '1204 Caroline St',
#         'crossStreet': 'at Dallas St',
#         'lat': 29.75382168551953,
#         'lng': -95.36395307867377,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75382168551953,
#           'lng': -95.36395307867377}],
#         'distance': 674,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1204 Caroline St (at Dallas St)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e5931735',
#          'name': 'Music Venue',
#          'pluralName': 'Music Venues',
#          'shortName': 'Music Venue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '39508193'}},
#       'referralId': 'e-0-4ada75a8f964a520c32221e3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5cc1f4de2f97ec002c3a296d',
#        'name': 'Shake Shack',
#        'location': {'lat': 29.759176,
#         'lng': -95.36335,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.759176,
#           'lng': -95.36335}],
#         'distance': 420,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Houston, TX 77002', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1400856',
#         'url': 'https://www.grubhub.com/restaurant/shake-shack-702-main-st-houston/1400856?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1400856',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5cc1f4de2f97ec002c3a296d-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bac0527f964a5208dde3ae3',
#        'name': 'The Lancaster Hotel',
#        'location': {'address': '701 Texas Avenue',
#         'crossStreet': 'Louisiana',
#         'lat': 29.761408733425917,
#         'lng': -95.36501573896328,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.761408733425917,
#           'lng': -95.36501573896328}],
#         'distance': 377,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['701 Texas Avenue (Louisiana)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '529327573'}},
#       'referralId': 'e-0-4bac0527f964a5208dde3ae3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba3ca66f964a520a95f38e3',
#        'name': 'Tranquility Park',
#        'location': {'address': '400 Rusk',
#         'crossStreet': 'Rusk at Bagby',
#         'lat': 29.760053085786517,
#         'lng': -95.36806799414663,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.760053085786517,
#           'lng': -95.36806799414663}],
#         'distance': 129,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['400 Rusk (Rusk at Bagby)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba3ca66f964a520a95f38e3-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ca536d898fbfc002cda8231',
#        'name': 'Goode Co. Taqueria',
#        'location': {'address': '712 Main St',
#         'lat': 29.758861541748047,
#         'lng': -95.3637924194336,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.758861541748047,
#           'lng': -95.3637924194336}],
#         'distance': 377,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['712 Main St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d151941735',
#          'name': 'Taco Place',
#          'pluralName': 'Taco Places',
#          'shortName': 'Tacos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ca536d898fbfc002cda8231-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c165e95b7b9c928c854ae37',
#        'name': "Miller's Cafe",
#        'location': {'address': 'Tunnels',
#         'lat': 29.75653581200845,
#         'lng': -95.36427900236197,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75653581200845,
#           'lng': -95.36427900236197}],
#         'distance': 425,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Tunnels', 'Houston, TX 77002', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1913718',
#         'url': 'https://www.grubhub.com/restaurant/millers-cafe-1001-mckinney-street-houston/1913718?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1913718',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c165e95b7b9c928c854ae37-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e1c6a131838367bcf6c6355',
#        'name': 'Berkeley Eye Center - The Park Shops',
#        'location': {'address': '1200 McKinney St Ste 411',
#         'lat': 29.75766313118798,
#         'lng': -95.36290166681026,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75766313118798,
#           'lng': -95.36290166681026}],
#         'distance': 484,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1200 McKinney St Ste 411',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4d954afda243a5684865b473',
#          'name': 'Optical Shop',
#          'pluralName': 'Optical Shops',
#          'shortName': 'Optical',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e1c6a131838367bcf6c6355-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5875728076f2ca32f4c39cef',
#        'name': 'Local Foods',
#        'location': {'address': '420 Main St',
#         'crossStreet': 'Prairie',
#         'lat': 29.7608788801562,
#         'lng': -95.36204248120119,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7608788801562,
#           'lng': -95.36204248120119}],
#         'distance': 587,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['420 Main St (Prairie)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f1',
#          'name': 'Bistro',
#          'pluralName': 'Bistros',
#          'shortName': 'Bistro',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5875728076f2ca32f4c39cef-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c75c84a1b30a0934884f009',
#        'name': 'Market Square Park',
#        'location': {'address': '300 Travis St',
#         'crossStreet': 'Preston',
#         'lat': 29.762556195955845,
#         'lng': -95.36213706082965,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.762556195955845,
#           'lng': -95.36213706082965}],
#         'distance': 671,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['300 Travis St (Preston)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c75c84a1b30a0934884f009-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5abd1e46d7627e445a979d65',
#        'name': 'Chick-fil-A',
#        'location': {'address': '500 Dallas St Ste T50',
#         'lat': 29.7577256,
#         'lng': -95.3704369,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7577256,
#           'lng': -95.3704369}],
#         'distance': 297,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['500 Dallas St Ste T50',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5abd1e46d7627e445a979d65-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b11cb7ff964a520ca8423e3',
#        'name': "Birraporetti's",
#        'location': {'address': '500 Louisiana St',
#         'crossStreet': 'Prairie St',
#         'lat': 29.762461731403604,
#         'lng': -95.36466977857937,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.762461731403604,
#           'lng': -95.36466977857937},
# ...
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6a250ef964a52018ca2be3-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59270c7b2aff31789d6dff96',
#        'name': 'Le Méridien Houston Downtown',
#        'location': {'address': '1121 Walker St',
#         'lat': 29.7569038,
#         'lng': -95.362806,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7569038,
#           'lng': -95.362806},
#          {'label': 'entrance', 'lat': 29.756893, 'lng': -95.362787}],
#         'distance': 524,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1121 Walker St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59270c7b2aff31789d6dff96-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a3b1487f964a5208aa01fe3',
#        'name': 'Char Bar',
#        'location': {'address': '305 Travis St',
#         'crossStreet': 'Congress',
#         'lat': 29.762598543087847,
#         'lng': -95.36177880685885,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.762598543087847,
#           'lng': -95.36177880685885},
#          {'label': 'entrance', 'lat': 29.762454, 'lng': -95.36144}],
#         'distance': 702,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['305 Travis St (Congress)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a3b1487f964a5208aa01fe3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b44cf2df964a520d7fc25e3',
#        'name': 'Doozo Dumpling House',
#        'location': {'address': '1200 McKinney St',
#         'crossStreet': 'The Park Shops',
#         'lat': 29.75524027697844,
#         'lng': -95.36216535901453,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75524027697844,
#           'lng': -95.36216535901453}],
#         'distance': 674,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1200 McKinney St (The Park Shops)',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d108941735',
#          'name': 'Dumpling Restaurant',
#          'pluralName': 'Dumpling Restaurants',
#          'shortName': 'Dumplings',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dumplings_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b44cf2df964a520d7fc25e3-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '537b6d00498ee7c8fb3641c9',
#        'name': 'Public Services Wine & Whiskey',
#        'location': {'address': '202 Travis St Ste 100',
#         'crossStreet': 'Franklin St',
#         'lat': 29.763508796585683,
#         'lng': -95.36113463503298,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.763508796585683,
#           'lng': -95.36113463503298}],
#         'distance': 813,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['202 Travis St Ste 100 (Franklin St)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2279280',
#         'url': 'https://www.grubhub.com/restaurant/public-services-bar-202-travis-street-houston/2279280?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2279280',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-537b6d00498ee7c8fb3641c9-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c606f9b4f0e580039b4e5ca',
#        'name': 'Bravery Chef Hall',
#        'location': {'address': '409 Travis St',
#         'lat': 29.761564,
#         'lng': -95.362132,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.761564,
#           'lng': -95.362132}],
#         'distance': 612,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['409 Travis St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c606f9b4f0e580039b4e5ca-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56fef76a498e5c35b07db082',
#        'name': 'Hampton Inn by Hilton',
#        'location': {'address': '710 Crawford St',
#         'lat': 29.7557072,
#         'lng': -95.3584477,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7557072,
#           'lng': -95.3584477}],
#         'distance': 963,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['710 Crawford St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56fef76a498e5c35b07db082-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5700337e498eb9256c8beaae',
#        'name': 'Homewood Suites by Hilton',
#        'location': {'address': '710 Crawford St',
#         'lat': 29.755714035130282,
#         'lng': -95.35835552429965,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.755714035130282,
#           'lng': -95.35835552429965},
#          {'label': 'entrance', 'lat': 29.755743, 'lng': -95.35868}],
#         'distance': 971,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['710 Crawford St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5700337e498eb9256c8beaae-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5352707c498e255471a027d0',
#        'name': 'Lone Star Taco Co.',
#        'location': {'address': '1001 Texas St',
#         'crossStreet': 'Main St.',
#         'lat': 29.75991427897547,
#         'lng': -95.36246599058904,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75991427897547,
#           'lng': -95.36246599058904}],
#         'distance': 517,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1001 Texas St (Main St.)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d151941735',
#          'name': 'Taco Place',
#          'pluralName': 'Taco Places',
#          'shortName': 'Tacos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1582765',
#         'url': 'https://www.grubhub.com/restaurant/lone-star-taco-1001-texas-avenue-houston/1582765?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1582765',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5352707c498e255471a027d0-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50ec655be4b02d8f193e4bf9',
#        'name': "Barnaby's Cafe",
#        'location': {'address': '801 Congress St',
#         'crossStreet': 'Milam St',
#         'lat': 29.763241691061875,
#         'lng': -95.36239097852939,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.763241691061875,
#           'lng': -95.36239097852939}],
#         'distance': 701,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['801 Congress St (Milam St)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1568901',
#         'url': 'https://www.grubhub.com/restaurant/barnabys-cafe-801-congress-street-houston/1568901?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1568901',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50ec655be4b02d8f193e4bf9-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5674c936498eafd4110efa65',
#        'name': 'La Calle Tacos',
#        'location': {'address': '909 Franklin St',
#         'crossStreet': 'Between Travis And Main',
#         'lat': 29.76346465520545,
#         'lng': -95.36066293716429,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.76346465520545,
#           'lng': -95.36066293716429}],
#         'distance': 846,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['909 Franklin St (Between Travis And Main)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d151941735',
#          'name': 'Taco Place',
#          'pluralName': 'Taco Places',
#          'shortName': 'Tacos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '326249',
#         'url': 'https://www.grubhub.com/restaurant/la-calle-tacos-909-franklin-st-houston/326249?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=326249',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '359676958'}},
#       'referralId': 'e-0-5674c936498eafd4110efa65-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0eddf5f964a5201d5c23e3',
#        'name': 'Downtown Aquarium',
#        'location': {'address': '410 Bagby St',
#         'crossStreet': 'at Preston St',
#         'lat': 29.76427027070077,
#         'lng': -95.3673791885376,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.76427027070077,
#           'lng': -95.3673791885376},
#          {'label': 'entrance', 'lat': 29.76419, 'lng': -95.367244}],
#         'distance': 594,
#         'postalCode': '77002',
#         'cc': 'US',
#         'neighborhood': 'Downtown Houston',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['410 Bagby St (at Preston St)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4fceea171983d5d06c3e9823',
#          'name': 'Aquarium',
#          'pluralName': 'Aquariums',
#          'shortName': 'Aquarium',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/aquarium_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '407499',
#         'url': 'https://www.grubhub.com/restaurant/aquarium-410-bagby-st-houston/407499?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=407499',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0eddf5f964a5201d5c23e3-99'}]}]}}

# %% [markdown]
# function that extracts the category of the venue - borrow from the Foursquare lab

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
SGnearby_venues = json_normalize(venues) # flatten JSON
# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
SGnearby_venues =SGnearby_venues.loc[:, filtered_columns]
# filter the category for each row
SGnearby_venues['venue.categories'] = SGnearby_venues.apply(get_category_type, axis=1)
# clean columns
SGnearby_venues.columns = [col.split(".")[-1] for col in SGnearby_venues.columns]

SGnearby_venues.shape
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# (100, 4)

# %%
SGnearby_venues.head(10)
# Out:
#                                    name             categories        lat  \
# 0                Mango Tree Thai Bistro        Thai Restaurant  29.758251
# 1                          Jason's Deli             Food Truck  29.757464
# 2  Hobby Center for the Performing Arts  Performing Arts Venue  29.761526
# 3                           Becks Prime           Burger Joint  29.758185
# 4                         Alley Theatre                Theater  29.761671
# 5                            Jones Hall           Concert Hall  29.761240
# 6                      Bombay Pizza Co.            Pizza Place  29.757700
# 7                              Perbacco     Italian Restaurant  29.760257
# 8             City Hall Farmer's Market         Farmers Market  29.759164
# 9                      Sam Houston Park                   Park  29.759876
#
#          lng
# 0 -95.365387
# 1 -95.365543
# 2 -95.369376
# 3 -95.366172
# 4 -95.365313
# 5 -95.365301
# 6 -95.364586
# 7 -95.364773
# 8 -95.368446
# 9 -95.371211

# %% [markdown]
# Map of Houston with venues in Neighborhood - for reference

# %%
# create map of Houston Texas using latitude and longitude values
map_hou = folium.Map(location=[latitude, longitude], zoom_start=18)
# add markers to map
for lat, lng, label in zip(SGnearby_venues['lat'], SGnearby_venues['lng'], SGnearby_venues['name']):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=30,
        radius=7,
        popup=label,
        color='blue',
        fill_color='#0f0f0f',
        fill_opacity=0.6,
    ).add_to(map_hou)  
    
map_hou
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# HOUSTON NEIGHBORHOODS - DATA AND MAPPING

# %%
import folium # map rendering library
from folium import plugins

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

import seaborn as sns

# import k-means from clustering stage
from sklearn.cluster import KMeans

# %%
import requests
import pandas as pd

url = 'https://en.wikipedia.org/wiki/List_of_Houston_neighborhoods#Alphabetical_list_of_neighborhoods'
response = requests.get(url)

tables = pd.read_html(response.text)

# write list houston neighborhood table data into `hous neigh_data` csv file
tables[0].to_csv("hous neigh_data.csv")

# %% [markdown]
# HOUSTON NEIGHBORHOODS - DATA AND MAPPING

# %%
houston_data  = pd.read_csv('hous neigh_data.csv') 
houston_data.head()
# Out:
#    Unnamed: 0  #                            Name  \
# 0           0  1                     Willowbrook
# 1           1  2             Greater Greenspoint
# 2           2  3                      Carverdale
# 3           3  4  Fairbanks / Northwest Crossing
# 4           4  5                  Greater Inwood
#
#   Location relative to Downtown Houston  \
# 0                             Northwest
# 1                                 North
# 2                             Northwest
# 3                             Northwest
# 4                             Northwest
#
#                               Approximate boundaries
# 0  Along Texas State Highway 249 northwest of Bel...
# 1  Around the junction of Beltway 8 and Interstat...
# 2  South of the junction of Beltway 8 and U.S. Ro...
# 3  Along U.S. Route 290 between Interstate 610 an...
# 4  North of Fairbanks / Northwest Crossing and ea...

# %%
from urllib.request import urlopen as uReq
import pandas as pd

url = 'https://en.wikipedia.org/wiki/List_of_Houston_neighborhoods'
response = uReq(url)
tables = pd.read_html(response.read())
#select only Name and Location column
select_table_column = ["Name","Location relative to Downtown Houston"]
'''
    #or select multiple columns 
    select_table_column = ["Name","Location relative to Downtown Houston"]

'''
# filter table data by selected columns
name = tables[0][select_table_column]


# # write name table data into `hou neigh_data` csv file and set csv header
name.to_csv("hou neigh_data.csv",header=True)

# %%
houston_data  = pd.read_csv('hou neigh_data.csv') 
houston_data.head()
# Out:
#    Unnamed: 0                            Name
# 0           0                     Willowbrook
# 1           1             Greater Greenspoint
# 2           2                      Carverdale
# 3           3  Fairbanks / Northwest Crossing
# 4           4                  Greater Inwood

# %%
houston_data.rename(columns={'Name' : 'H Neighborhood '}, inplace=True)
houston_data.head()
# Out:
#    Unnamed: 0                 H Neighborhood
# 0           0                     Willowbrook
# 1           1             Greater Greenspoint
# 2           2                      Carverdale
# 3           3  Fairbanks / Northwest Crossing
# 4           4                  Greater Inwood

# %%
houston_data.tail()
# Out:
#     Unnamed: 0         H Neighborhood
# 83          83     Spring Branch North
# 84          84   Spring Branch Central
# 85          85      Spring Branch East
# 86          86  Greenway / Upper Kirby
# 87          87      Lawndale / Wayside

# %%
#Defining a function to get the location of the localities
def get_location(localities):
    g = geocoder.arcgis('{}, Houston, US'.format(localities))
    get_latlng = g.latlng
    return get_latlng

# %%
#Creating an empty list
co_ordinates = []
#Getting the co-ordinates of each locality using the function defined above
for i in houston_data["H Neighborhood"].tolist():
    co_ordinates.append(get_location(i)) 
print(co_ordinates)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'H Neighborhood'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-44a597466f03> in <module>
#       2 co_ordinates = []
#       3 #Getting the co-ordinates of each locality using the function defined above
# ----> 4 for i in houston_data["H Neighborhood"].tolist():
#       5     co_ordinates.append(get_location(i))
#       6 print(co_ordinates)
#
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'H Neighborhood'

# %%
#Creating a dataframe from the list of location co-ordinates
co_ordinates_houston_data = pd.DataFrame(co_ordinates, columns=['Latitudes', 'Longitudes'])

# %%
#Adding co-ordinates of localities to df dataframe
houston_data["Latitudes"] = co_ordinates_houston_data["Latitudes"]
houston_data["Longitudes"] = co_ordinates_houston_data["Longitudes"]

# %%
print("The shape of df is {}".format(houston_data.shape))
houston_data.head()
# Out:
# The shape of df is (88, 4)
#    Unnamed: 0                 H Neighborhood  Latitudes Longitudes
# 0           0                     Willowbrook       NaN        NaN
# 1           1             Greater Greenspoint       NaN        NaN
# 2           2                      Carverdale       NaN        NaN
# 3           3  Fairbanks / Northwest Crossing       NaN        NaN
# 4           4                  Greater Inwood       NaN        NaN

# %% [markdown]
# Plotting Houston Neighborhood on map

# %%
#Creating a map
Houston_map = folium.Map(location=[houston_lat, houston_lng],zoom_start=11)

#adding markers to the map for localities
#marker for Houston
folium.Marker([houston_lat, houston_lng], popup='<i>Houston</i>', color='red', tooltip="Click to see").add_to(Houston_map)

#markers for localities
for latitude,longitude,name in zip(houston_data["Latitudes"], houston_data["Longitudes"], houston_data["H Neighborhood"]):
    folium.CircleMarker(
        [latitude, longitude],
        radius=6,
        color='blue',
        popup=name,
        fill=True,
        fill_color='#3186ff'
    ).add_to(Houston_map)

Houston_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-c297a8f2a148> in <module>
#       1 #Creating a map
# ----> 2 Houston_map = folium.Map(location=[houston_lat, houston_lng],zoom_start=11)
#       3
#       4 #adding markers to the map for localities
#       5 #marker for Houston
#
# NameError: name 'houston_lat' is not defined

# %% [markdown]
# Houston neighborhoods - data with top 10 clustered venues

# %% [markdown]
# Map of Houston neighborhoods with top 10 clustered venues popus allow to identify each neighborhood and the cluster of venues around it in order to proceed to examine in more detail in the next cell

# %%
# create map of Houston using latitude and longitude values from Nominatim
latitude= 29.7589382 
longitude= -95.3676974

kclusters=5
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=13)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(houston_data['Latitude'], houston_data['Longitude'], houston_data['Name'], houston_data['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=20,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
map_clusters

# %%
Using Foursquare API to explore the localities

# %%
#Foursquare Credentials
CLIENT_ID = '1CVX0P22PGNHR2GYDNEIYSSE5UZHVOGVTVADWQXJ5NF5BKJ1'
CLIENT_SECRET = 'NU3QOJRDYYVJN0125XOZDZFQGLYVYSC5R5IEGBHXHL0SFFRO'
VERSION = '20180604'

# %%
#Getting the top 100 venues in each locality
radius = 2000
LIMIT = 100

venues = []

for lat, lng, locality in zip(houston_data["Latitudes"], houston_data["Longitudes"], houston_data["H Neighborhood"]):
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat, lng, VERSION, radius, LIMIT)
    results = requests.get(url).json()['response']['groups'][0]['items']

    for venue in results:
        venues.append((locality, lat, lng, venue['venue']['H Neighborhood'], venue['venue']['location']['lat'], venue['venue']['location']['lng'], venue['venue']['categories'][0]['name'], venue['venue']['id']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'H Neighborhood'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-03aeab2375b6> in <module>
#       5 venues = []
#       6
# ----> 7 for lat, lng, locality in zip(houston_data["Latitudes"], houston_data["Longitudes"], houston_data["H Neighborhood"]):
#       8     url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat, lng, VERSION, radius, LIMIT)
#       9     results = requests.get(url).json()['response']['groups'][0]['items']
#
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'H Neighborhood'

# %% [markdown]
# Plotting the Neighborhood on map

# %%
#Convert the venue list into dataframe
venues_houston_data = pd.DataFrame(venues)
venues_houston_data.columns = ['Locality', 'Latitude', 'Longitude', 'Venue H Neighborhood', 'Venue Lat', 'Venue Lng', 'Venue Category', 'Venue ID']
venues_houston_data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-700c7595accd> in <module>
#       1 #Convert the venue list into dataframe
#       2 venues_houston_data = pd.DataFrame(venues)
# ----> 3 venues_houston_data.columns = ['Locality', 'Latitude', 'Longitude', 'Venue H Neighborhood', 'Venue Lat', 'Venue Lng', 'Venue Category', 'Venue ID']
#       4 venues_houston_data.head()
#
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5152         try:
#    5153             object.__getattribute__(self, name)
# -> 5154             return object.__setattr__(self, name, value)
#    5155         except AttributeError:
#    5156             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     225         if new_len != old_len:
#     226             raise ValueError(
# --> 227                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     228                 f"values have {new_len} elements"
#     229             )
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 8 elements
